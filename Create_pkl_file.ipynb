# %% [markdown]
# ## Creating a the pkl file

# %%
#!/usr/bin/env python
# coding: utf-8

import numpy as np 
import pandas as pd
import pickle
from sklearn.tree import DecisionTreeClassifier


# ## Python code for prediction the state of the drill 


# **Getting the data** importing from the file 


my_data = pd.read_csv("data_case_study.csv", delimiter=",")
my_data.head()




# Droping the first and timestamp column



my_data = my_data.drop(['Unnamed: 0','timestamp'], axis=1)




# Keping the target column, which in this case is the status of the drill



my_data_target = my_data['activity']
my_data_target.head()


# ## Keeping the Columns with numerical values. I could also dummy the non-numerical indices but for these particular project it is not necessary 



columns = ['engine_speed','hydraulic_drive_off','drill_boom_in_anchor_position','pvalve_drill_forward','hydraulic_pump','bolt','boom_lift','boom_lower','boom_forward','boom_backward','drill_boom_turn_left','drill_boom_turn_right','drill_boom_turn_forward','drill_boom_turn_backward','beam_right','beam_left','anchor']
my_data = my_data[columns]
my_data.head()


# It looks like some column includes some values that are not numerical. We can fill those rows with the mean value of each column numerical value



my_data = my_data.fillna(my_data.mean())


# Set the independent variable 

X = my_data[columns].values
X[0:1]


# Now we can fill the target variable.


y = my_data_target.values


from sklearn.model_selection import train_test_split


X_trainset, X_testset, y_trainset, y_testset = train_test_split(X, y, test_size=0.3, random_state=3)


# Ensurig the dimensions match. Uncomment if needed


#print('Shape of X training set {}'.format(X_trainset.shape),'&',' Size of Y training set {}'.format(y_trainset.shape)),
#print('Shape of X test set {}'.format(X_testset.shape),'&',' Size of Y test set {}'.format(y_testset.shape))



drillTree = DecisionTreeClassifier(criterion="entropy", max_depth = 5)


drillTree.fit(X_trainset,y_trainset)

# Serialize the model
with open('drill_model.pkl', 'wb') as file:
    pickle.dump(drillTree, file)
# Out:
# /Users/juancarlos/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.0' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /Users/juancarlos/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:62: UserWarning: Pandas requires version '1.3.4' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (
# /Users/juancarlos/opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
